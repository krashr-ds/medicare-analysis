# %% [markdown]
# # Descriptive Exploration PUF and Counties Aggregate Data
#
# DeSYNPuf Counties Aggregate with Elixhauser Sums per User & RWJF Factor Rankings Dataset

# %%
# %matplotlib inline
import random
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.rcsetup as mrc

# %% [markdown]
# The file contains aggregated Medicare data from 2008-2010 (DeSYNPuf Synthetic Public Use Files), and RWJF County Health Factors and Outcomes Ranking Data from 2010.
#
# 2960 out of 3012 counties (98%) had a Medicare beneficiary with at least one inpatient or outpatient claim filed between 2008 and 2010.

# %%
medicare_counties = pd.read_csv("/home/kylier/python/DS/data/PUF/PUF_RWJF_MERGED.csv")
medicare_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3010 entries, 0 to 3009
# Data columns (total 68 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3010 non-null   int64
#  1   Unnamed: 0.1           3010 non-null   int64
#  2   FIPS_STATE_CODE        3010 non-null   float64
#  3   FIPS_COUNTY_CODE       3010 non-null   float64
#  4   CNTY_BENE_CT           3010 non-null   int64
#  5   CNTY_BENE_USRS         3010 non-null   int64
#  6   CNTY_MEAN_AGE          2957 non-null   float64
#  7   CNTY_SEX_PROP          3010 non-null   float64
#  8   TOT_CNCR_CASES         3010 non-null   float64
#  9   TOT_STRKETIA_CASES     3010 non-null   float64
#  10  TOT_ESRD_CASES         3010 non-null   float64
#  11  CNTY_TOT_VSTS          3010 non-null   int64
#  12  CNTY_TOT_IP_VSTS       3010 non-null   int64
#  13  CNTY_TOT_OP_VSTS       3010 non-null   int64
#  14  CNTY_TOT_CODES         3010 non-null   float64
#  15  CNTY_TOT_PROCS         3010 non-null   float64
#  16  CNTY_MEAN_IP_STAY      3010 non-null   float64
#  17  CBSA                   1091 non-null   float64
#  18  CNTY_TOT_CCS           3010 non-null   float64
#  19  CNTY_MEAN_CCS          3010 non-null   float64
#  20  CNTY_TOT_NEW_CCS       3010 non-null   float64
#  21  CNTY_MEAN_NEW_CCS      3010 non-null   float64
#  22  CNTY_SUM_ELIX_SCORES   3010 non-null   float64
#  23  CNTY_TOT_IP_COST       3010 non-null   float64
#  24  CNTY_TOT_OP_COST       3010 non-null   float64
#  25  CNTY_ALL_COSTS         3010 non-null   float64
#  26  CNTY_PERCENT_COSTS     3010 non-null   float64
#  27  CNTY_USR_PROP          3010 non-null   float64
#  28  CNTY_IP_PROP           2957 non-null   float64
#  29  CNTY_AGE_95CIL         2766 non-null   float64
#  30  CNTY_AGE_95CIU         2766 non-null   float64
#  31  CNTY_PROP_NH_WHITE     3010 non-null   float64
#  32  CNTY_PROP_AA_BLACK     3010 non-null   float64
#  33  CNTY_PROP_OTHER        3010 non-null   float64
#  34  CNTY_PROP_NW_HISPANIC  3010 non-null   float64
#  35  TOT_CNCR_PREV          3010 non-null   float64
#  36  TOT_STRK_PREV          3010 non-null   float64
#  37  TOT_ESRD_PREV          3010 non-null   float64
#  38  TOT_CVRG_MOS_PB_PY     3010 non-null   float64
#  39  TOT_RXCVRG_MOS_PB_PY   3010 non-null   float64
#  40  TOT_VSTS_PB            3010 non-null   float64
#  41  TOT_VSTS_PU            2957 non-null   float64
#  42  TOT_IP_VSTS_PU         2957 non-null   float64
#  43  TOT_OP_VSTS_PU         2957 non-null   float64
#  44  CODES_PU               2957 non-null   float64
#  45  PROCS_PU               2957 non-null   float64
#  46  PRVDRS_PU              2957 non-null   float64
#  47  TOT_IPDAYS_PU          2957 non-null   float64
#  48  TOT_CC_PREV            3010 non-null   float64
#  49  TOT_CCS_PU             2971 non-null   float64
#  50  TOT_CC_INCD            3010 non-null   float64
#  51  TOT_NEW_CC_PU          2966 non-null   float64
#  52  TOT_ELIX_PU            2957 non-null   float64
#  53  TOT_IP_COST_PB         3010 non-null   float64
#  54  TOT_OP_COST_PB         3010 non-null   float64
#  55  TOT_COST_PB            3010 non-null   float64
#  56  FIPS                   3009 non-null   float64
#  57  STATE                  3009 non-null   object
#  58  COUNTY                 3009 non-null   object
#  59  NUM_COUNTIES           3009 non-null   float64
#  60  HO_RANK                2949 non-null   float64
#  61  HO_PROP_RANK           2949 non-null   float64
#  62  HO_QUARTILE            2949 non-null   float64
#  63  HF_RANK                2949 non-null   float64
#  64  HF_PROP_RANK           2949 non-null   float64
#  65  HF_QUARTILE            2949 non-null   float64
#  66  StateCode              3009 non-null   float64
#  67  CountyFIPS             3009 non-null   float64
# dtypes: float64(59), int64(7), object(2)
# memory usage: 1.6+ MB

# %%
medicare_counties.drop(columns=medicare_counties.columns[0], axis=1, inplace=True, errors="ignore")
medicare_counties.drop(columns=medicare_counties.columns[0], axis=1, inplace=True, errors="ignore")
medicare_counties.columns=medicare_counties.columns.str.strip()
medicare_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3010 entries, 0 to 3009
# Data columns (total 66 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS_STATE_CODE        3010 non-null   float64
#  1   FIPS_COUNTY_CODE       3010 non-null   float64
#  2   CNTY_BENE_CT           3010 non-null   int64
#  3   CNTY_BENE_USRS         3010 non-null   int64
#  4   CNTY_MEAN_AGE          2957 non-null   float64
#  5   CNTY_SEX_PROP          3010 non-null   float64
#  6   TOT_CNCR_CASES         3010 non-null   float64
#  7   TOT_STRKETIA_CASES     3010 non-null   float64
#  8   TOT_ESRD_CASES         3010 non-null   float64
#  9   CNTY_TOT_VSTS          3010 non-null   int64
#  10  CNTY_TOT_IP_VSTS       3010 non-null   int64
#  11  CNTY_TOT_OP_VSTS       3010 non-null   int64
#  12  CNTY_TOT_CODES         3010 non-null   float64
#  13  CNTY_TOT_PROCS         3010 non-null   float64
#  14  CNTY_MEAN_IP_STAY      3010 non-null   float64
#  15  CBSA                   1091 non-null   float64
#  16  CNTY_TOT_CCS           3010 non-null   float64
#  17  CNTY_MEAN_CCS          3010 non-null   float64
#  18  CNTY_TOT_NEW_CCS       3010 non-null   float64
#  19  CNTY_MEAN_NEW_CCS      3010 non-null   float64
#  20  CNTY_SUM_ELIX_SCORES   3010 non-null   float64
#  21  CNTY_TOT_IP_COST       3010 non-null   float64
#  22  CNTY_TOT_OP_COST       3010 non-null   float64
#  23  CNTY_ALL_COSTS         3010 non-null   float64
#  24  CNTY_PERCENT_COSTS     3010 non-null   float64
#  25  CNTY_USR_PROP          3010 non-null   float64
#  26  CNTY_IP_PROP           2957 non-null   float64
#  27  CNTY_AGE_95CIL         2766 non-null   float64
#  28  CNTY_AGE_95CIU         2766 non-null   float64
#  29  CNTY_PROP_NH_WHITE     3010 non-null   float64
#  30  CNTY_PROP_AA_BLACK     3010 non-null   float64
#  31  CNTY_PROP_OTHER        3010 non-null   float64
#  32  CNTY_PROP_NW_HISPANIC  3010 non-null   float64
#  33  TOT_CNCR_PREV          3010 non-null   float64
#  34  TOT_STRK_PREV          3010 non-null   float64
#  35  TOT_ESRD_PREV          3010 non-null   float64
#  36  TOT_CVRG_MOS_PB_PY     3010 non-null   float64
#  37  TOT_RXCVRG_MOS_PB_PY   3010 non-null   float64
#  38  TOT_VSTS_PB            3010 non-null   float64
#  39  TOT_VSTS_PU            2957 non-null   float64
#  40  TOT_IP_VSTS_PU         2957 non-null   float64
#  41  TOT_OP_VSTS_PU         2957 non-null   float64
#  42  CODES_PU               2957 non-null   float64
#  43  PROCS_PU               2957 non-null   float64
#  44  PRVDRS_PU              2957 non-null   float64
#  45  TOT_IPDAYS_PU          2957 non-null   float64
#  46  TOT_CC_PREV            3010 non-null   float64
#  47  TOT_CCS_PU             2971 non-null   float64
#  48  TOT_CC_INCD            3010 non-null   float64
#  49  TOT_NEW_CC_PU          2966 non-null   float64
#  50  TOT_ELIX_PU            2957 non-null   float64
#  51  TOT_IP_COST_PB         3010 non-null   float64
#  52  TOT_OP_COST_PB         3010 non-null   float64
#  53  TOT_COST_PB            3010 non-null   float64
#  54  FIPS                   3009 non-null   float64
#  55  STATE                  3009 non-null   object
#  56  COUNTY                 3009 non-null   object
#  57  NUM_COUNTIES           3009 non-null   float64
#  58  HO_RANK                2949 non-null   float64
#  59  HO_PROP_RANK           2949 non-null   float64
#  60  HO_QUARTILE            2949 non-null   float64
#  61  HF_RANK                2949 non-null   float64
#  62  HF_PROP_RANK           2949 non-null   float64
#  63  HF_QUARTILE            2949 non-null   float64
#  64  StateCode              3009 non-null   float64
#  65  CountyFIPS             3009 non-null   float64
# dtypes: float64(59), int64(5), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# Here are the counties with no Medicare claimants for the period.
#
# (We know they had no claimants, because age was calculated for beneficiaries based on their claim dates, either for inpatient or outpatient.)
#
# Some have high RWJF rankings (closer to 1) and some have low rankings.
#
# A few are part of Metropolitan or Micropolitan Statistical Areas (CBSA)s.

# %%
no_claims = medicare_counties[medicare_counties["CNTY_MEAN_AGE"].isnull()]
nc_summary = no_claims[["STATE", "COUNTY", "HF_PROP_RANK", "HO_PROP_RANK"]]
nc_summary.sort_values(by=["HF_PROP_RANK", "HO_PROP_RANK"])
# Out:
#               STATE        COUNTY  HF_PROP_RANK  HO_PROP_RANK
# 2326   South Dakota          Todd         0.018         0.070
# 1584        Montana     Roosevelt         0.023         0.000
# 1949   North Dakota         Sioux         0.023         0.000
# 872          Kansas           Elk         0.030         0.101
# 279        Colorado      Saguache         0.036         0.625
# 117        Arkansas         Desha         0.093         0.133
# 2400      Tennessee       Pickett         0.095         0.389
# 2825     Washington         Adams         0.154         0.436
# 898          Kansas       Lincoln         0.212         0.646
# 2373      Tennessee       Houston         0.263         0.263
# 258        Colorado          Lake         0.286         0.286
# 1348      Minnesota      Watonwan         0.306         0.612
# 2144         Oregon        Morrow         0.333         0.545
# 2097       Oklahoma      Okfuskee         0.390         0.247
# 2283   South Dakota         Clark         0.421         0.737
# 1373    Mississippi        Greene         0.457         0.877
# 272        Colorado      Phillips         0.518         0.446
# 2292   South Dakota       Douglas         0.526         0.298
# 601        Illinois        Jasper         0.554         0.505
# 1637       Nebraska       Johnson         0.560         0.613
# 1470       Missouri     Gasconade         0.617         0.626
# 1591        Montana         Teton         0.636         0.432
# 251        Colorado        Gilpin         0.643         0.536
# 3008        Wyoming      Washakie         0.652         0.783
# 403         Georgia      Crawford         0.656         0.732
# 2049       Oklahoma        Beaver         0.675         0.974
# 1722     New Mexico       De Baca         0.688         0.625
# 1048       Kentucky     Robertson         0.692         0.525
# 1569        Montana  Judith Basin         0.705         0.500
# 239        Colorado   Clear Creek         0.714         0.393
# 2067       Oklahoma         Dewey         0.714         0.584
# 553           Idaho        Oneida         0.738         0.643
# 3004        Wyoming      Sublette         0.739         0.739
# 2418      Tennessee         Union         0.768         0.253
# 890          Kansas        Jewell         0.818         0.404
# 2898  West Virginia     Pleasants         0.836         0.655
# 1923   North Dakota        Foster         0.864         0.773
# 1079      Louisiana       Cameron         0.906         0.953
# 78              NaN           NaN           NaN           NaN
# 238        Colorado      Cheyenne           NaN           NaN
# 256        Colorado         Kiowa           NaN           NaN
# 942          Kansas       Wallace           NaN           NaN
# 1283      Minnesota          Cook           NaN           NaN
# 1652       Nebraska       Perkins           NaN           NaN
# 1727     New Mexico       Harding           NaN           NaN
# 1914   North Dakota         Burke           NaN           NaN
# 1948   North Dakota      Sheridan           NaN           NaN
# 2154         Oregon       Wheeler           NaN           NaN
# 2297   South Dakota          Hand           NaN           NaN
# 2325   South Dakota         Sully           NaN           NaN
# 2587          Texas        Oldham           NaN           NaN
# 2659           Utah       Daggett           NaN           NaN
# 2670           Utah          Rich           NaN           NaN

# %%
# Drop an empty row

medicare_counties.drop(medicare_counties.iloc[78].name,  inplace=True)

# %%
# Drop a handful of unranked counties

medicare_counties = medicare_counties.dropna(subset=['HO_RANK', 'HF_RANK'])

# %%
# Set per-User NaNs to Zeros

medicare_counties[['TOT_VSTS_PU', 'TOT_IP_VSTS_PU', 'TOT_OP_VSTS_PU', 'CODES_PU', 'PROCS_PU', 'PRVDRS_PU', 'TOT_IPDAYS_PU', 'TOT_CCS_PU', 'TOT_NEW_CC_PU', 'TOT_ELIX_PU']] = medicare_counties[['TOT_VSTS_PU', 'TOT_IP_VSTS_PU', 'TOT_OP_VSTS_PU', 'CODES_PU', 'PROCS_PU', 'PRVDRS_PU', 'TOT_IPDAYS_PU', 'TOT_CCS_PU', 'TOT_NEW_CC_PU', 'TOT_ELIX_PU']].fillna(value=0)

# %%
medicare_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2949 entries, 0 to 3009
# Data columns (total 66 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS_STATE_CODE        2949 non-null   float64
#  1   FIPS_COUNTY_CODE       2949 non-null   float64
#  2   CNTY_BENE_CT           2949 non-null   int64
#  3   CNTY_BENE_USRS         2949 non-null   int64
#  4   CNTY_MEAN_AGE          2911 non-null   float64
#  5   CNTY_SEX_PROP          2949 non-null   float64
#  6   TOT_CNCR_CASES         2949 non-null   float64
#  7   TOT_STRKETIA_CASES     2949 non-null   float64
#  8   TOT_ESRD_CASES         2949 non-null   float64
#  9   CNTY_TOT_VSTS          2949 non-null   int64
#  10  CNTY_TOT_IP_VSTS       2949 non-null   int64
#  11  CNTY_TOT_OP_VSTS       2949 non-null   int64
#  12  CNTY_TOT_CODES         2949 non-null   float64
#  13  CNTY_TOT_PROCS         2949 non-null   float64
#  14  CNTY_MEAN_IP_STAY      2949 non-null   float64
#  15  CBSA                   1091 non-null   float64
#  16  CNTY_TOT_CCS           2949 non-null   float64
#  17  CNTY_MEAN_CCS          2949 non-null   float64
#  18  CNTY_TOT_NEW_CCS       2949 non-null   float64
#  19  CNTY_MEAN_NEW_CCS      2949 non-null   float64
#  20  CNTY_SUM_ELIX_SCORES   2949 non-null   float64
#  21  CNTY_TOT_IP_COST       2949 non-null   float64
#  22  CNTY_TOT_OP_COST       2949 non-null   float64
#  23  CNTY_ALL_COSTS         2949 non-null   float64
#  24  CNTY_PERCENT_COSTS     2949 non-null   float64
#  25  CNTY_USR_PROP          2949 non-null   float64
#  26  CNTY_IP_PROP           2911 non-null   float64
#  27  CNTY_AGE_95CIL         2750 non-null   float64
#  28  CNTY_AGE_95CIU         2750 non-null   float64
#  29  CNTY_PROP_NH_WHITE     2949 non-null   float64
#  30  CNTY_PROP_AA_BLACK     2949 non-null   float64
#  31  CNTY_PROP_OTHER        2949 non-null   float64
#  32  CNTY_PROP_NW_HISPANIC  2949 non-null   float64
#  33  TOT_CNCR_PREV          2949 non-null   float64
#  34  TOT_STRK_PREV          2949 non-null   float64
#  35  TOT_ESRD_PREV          2949 non-null   float64
#  36  TOT_CVRG_MOS_PB_PY     2949 non-null   float64
#  37  TOT_RXCVRG_MOS_PB_PY   2949 non-null   float64
#  38  TOT_VSTS_PB            2949 non-null   float64
#  39  TOT_VSTS_PU            2949 non-null   float64
#  40  TOT_IP_VSTS_PU         2949 non-null   float64
#  41  TOT_OP_VSTS_PU         2949 non-null   float64
#  42  CODES_PU               2949 non-null   float64
#  43  PROCS_PU               2949 non-null   float64
#  44  PRVDRS_PU              2949 non-null   float64
#  45  TOT_IPDAYS_PU          2949 non-null   float64
#  46  TOT_CC_PREV            2949 non-null   float64
#  47  TOT_CCS_PU             2949 non-null   float64
#  48  TOT_CC_INCD            2949 non-null   float64
#  49  TOT_NEW_CC_PU          2949 non-null   float64
#  50  TOT_ELIX_PU            2949 non-null   float64
#  51  TOT_IP_COST_PB         2949 non-null   float64
#  52  TOT_OP_COST_PB         2949 non-null   float64
#  53  TOT_COST_PB            2949 non-null   float64
#  54  FIPS                   2949 non-null   float64
#  55  STATE                  2949 non-null   object
#  56  COUNTY                 2949 non-null   object
#  57  NUM_COUNTIES           2949 non-null   float64
#  58  HO_RANK                2949 non-null   float64
#  59  HO_PROP_RANK           2949 non-null   float64
#  60  HO_QUARTILE            2949 non-null   float64
#  61  HF_RANK                2949 non-null   float64
#  62  HF_PROP_RANK           2949 non-null   float64
#  63  HF_QUARTILE            2949 non-null   float64
#  64  StateCode              2949 non-null   float64
#  65  CountyFIPS             2949 non-null   float64
# dtypes: float64(59), int64(5), object(2)
# memory usage: 1.5+ MB

# %%
sb.set_theme(style="whitegrid", palette="crest")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
medicare_counties.hist("HF_PROP_RANK", ax=axes[0])
medicare_counties.hist("HO_PROP_RANK", ax=axes[1])
plt.show()

# %%
medicare_counties[medicare_counties["HF_PROP_RANK"]>.6]["HF_PROP_RANK"].value_counts(normalize=True)
# Out:
# 0.667    0.013901
# 0.750    0.013901
# 0.800    0.011295
# 0.955    0.008688
# 0.818    0.008688
#            ...
# 0.995    0.000869
# 0.823    0.000869
# 0.912    0.000869
# 0.771    0.000869
# 0.681    0.000869
# Name: HF_PROP_RANK, Length: 361, dtype: float64

# %%
medicare_counties.loc[medicare_counties["HF_PROP_RANK"]>=0.6, "HF_HIGH"] = 1
medicare_counties.loc[medicare_counties["HF_PROP_RANK"]<0.6, "HF_HIGH"] = 0

# %%
sb.set(rc={"figure.figsize":(15, 5)})
sb.set_theme(style="whitegrid")
sb.scatterplot(data=medicare_counties, x="HO_PROP_RANK", y="TOT_ELIX_PU", hue="HF_HIGH", palette="mako");

# %%
medicare_counties[medicare_counties["TOT_ELIX_PU"]>6]
# Out:
#       FIPS_STATE_CODE  FIPS_COUNTY_CODE  CNTY_BENE_CT  CNTY_BENE_USRS  \
# 1608             31.0              29.0             2               1
# 2797             51.0             595.0             2               2
#
#       CNTY_MEAN_AGE  CNTY_SEX_PROP  TOT_CNCR_CASES  TOT_STRKETIA_CASES  \
# 1608           71.3            1.0             1.0                 1.0
# 2797           54.9            1.0             1.0                 2.0
#
#       TOT_ESRD_CASES  CNTY_TOT_VSTS  ...  NUM_COUNTIES  HO_RANK  HO_PROP_RANK  \
# 1608             0.0              5  ...          75.0     44.0         0.413
# 2797             1.0             15  ...         132.0    131.0         0.008
#
#       HO_QUARTILE  HF_RANK  HF_PROP_RANK  HF_QUARTILE  StateCode  CountyFIPS  \
# 1608          3.0     19.0         0.747          1.0       31.0        29.0
# 2797          4.0    124.0         0.061          4.0       51.0       595.0
#
#       HF_HIGH
# 1608      1.0
# 2797      0.0
#
# [2 rows x 67 columns]

# %%
# Remove 2 Outliers

medicare_counties = medicare_counties[medicare_counties["TOT_ELIX_PU"]<6]

# %% [markdown]
# ## Mean Age, Prop Sex, and % Race

# %%
medicare_counties["CNTY_MEAN_AGE"] = medicare_counties["CNTY_MEAN_AGE"].round(decimals=1)

sb.set_theme(style="whitegrid", palette="mako")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))
medicare_counties.hist("CNTY_MEAN_AGE", ax=axes[0])
medicare_counties.hist("CNTY_SEX_PROP", ax=axes[1])
plt.show()

# %%
sb.set_theme(style="whitegrid", palette="mako")
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(40, 10))
medicare_counties.hist("CNTY_PROP_NH_WHITE", ax=axes[0])
medicare_counties.hist("CNTY_PROP_AA_BLACK", ax=axes[1])
medicare_counties.hist("CNTY_PROP_OTHER", ax=axes[2])
medicare_counties.hist("CNTY_PROP_NW_HISPANIC", ax=axes[3])
plt.show()

# %% [markdown]
# ## Case Counts
#
# Let's see how these case counts correlate with the County Health Rankings, Total Costs and Stay Information.

# %%
medicare_counties["TOT_ESRD_PREV"].value_counts(normalize=True)
# Out:
# 0.000000    0.183577
# 0.200000    0.044452
# 0.250000    0.043434
# 0.333333    0.040719
# 0.166667    0.040041
#               ...
# 0.242775    0.000339
# 0.219269    0.000339
# 0.205607    0.000339
# 0.161137    0.000339
# 0.121622    0.000339
# Name: TOT_ESRD_PREV, Length: 528, dtype: float64

# %%
sb.set_theme(style="whitegrid", palette="rocket")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
medicare_counties.hist("TOT_CNCR_PREV", ax=axes[0])
medicare_counties.hist("TOT_STRK_PREV", ax=axes[1])
plt.show()

# %%
sb.set_theme(style="whitegrid", palette="rocket")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
medicare_counties.hist("TOT_ESRD_PREV", ax=axes[0])
medicare_counties.hist("TOT_CC_PREV", ax=axes[1])
plt.show()

# %%
sb.set_theme(style="whitegrid", palette="mako")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))
medicare_counties.hist("TOT_CC_INCD", ax=axes[0])
medicare_counties.hist("TOT_ELIX_PU", ax=axes[1])
plt.show()

# %% [markdown]
# ## Severity Variable
#
# Elixhauser Score Total per User, cut at 1.5 to establish "High Severity" for a County

# %%
medicare_counties.loc[medicare_counties["TOT_ELIX_PU"]>=1.5, "HIGH_SEV"] = 1
medicare_counties.loc[medicare_counties["TOT_ELIX_PU"]<1.5, "HIGH_SEV"] = 0

# %%
sb.set_theme(style="whitegrid", palette="crest")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
medicare_counties.hist("TOT_COST_PB", ax=axes[0])
medicare_counties.hist("TOT_VSTS_PB", ax=axes[1])
plt.show()

# %%
sb.set_theme(style="whitegrid", palette="crest")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
medicare_counties.hist("CODES_PU", ax=axes[0])
medicare_counties.hist("PROCS_PU", ax=axes[1])
plt.show()

# %%
conditions = medicare_counties[["TOT_CC_PREV", "TOT_CC_INCD", "TOT_ELIX_PU", "TOT_VSTS_PB", "CNTY_IP_PROP", 
                                "TOT_IPDAYS_PU", "CODES_PU", "PROCS_PU", "PRVDRS_PU", "TOT_COST_PB", 
                                "HF_PROP_RANK", "HO_PROP_RANK", "CNTY_MEAN_AGE", "CNTY_SEX_PROP"]]
conditions_corr = conditions.corr(method="spearman")
lower_corr = conditions_corr.where(np.tril(np.ones(conditions_corr.shape)).astype(np.bool))

plt.rcParams["figure.figsize"] = (20.0, 20.0)
conditions_hmap=sb.heatmap(lower_corr, annot=True, cmap="mako", fmt=".2f")
fig = conditions_hmap.get_figure()
fig.tight_layout()
fig.savefig("counties_cases_heatmap.png")

# %%
sb.set_theme(style="whitegrid", palette="mako")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(30, 10))
medicare_counties.hist("TOT_IPDAYS_PU", ax=axes[0])
medicare_counties.hist("CNTY_MEAN_IP_STAY", ax=axes[1])
plt.show()

# %% [markdown]
# ## Systemic Procedure Overuse
#
# There are 1,762 counties where the number of procedures per user per county was **> 10** for the period.

# %%
medicare_counties.loc[medicare_counties["PROCS_PU"]>=10, "HIGH_PROCS"] = 1
medicare_counties.loc[medicare_counties["PROCS_PU"]<10, "HIGH_PROCS"] = 0

sb.set(rc={"figure.figsize":(15, 5)})
sb.set_theme(style="whitegrid")
sb.barplot(x="HF_HIGH", y="HIGH_PROCS", data=medicare_counties, palette="mako");

# %%
sb.set(rc={"figure.figsize":(15, 5)})
sb.set_theme(style="whitegrid")
sb.barplot(x="HF_HIGH", y="HIGH_SEV", data=medicare_counties, palette="mako");

# %% [markdown]
# ## Super Users!
#
# So, here are 160 Super-Utilizing Counties!

# %%
medicare_counties["DIVERSE_PROP"] = 1 - medicare_counties["CNTY_PROP_NH_WHITE"]

# %%
su = medicare_counties[(medicare_counties["TOT_IPDAYS_PU"]>15) | (medicare_counties["TOT_COST_PB"]>150000)]

# %%
cc = su[["STATE", "COUNTY", "CNTY_MEAN_AGE", "CNTY_SEX_PROP", "CNTY_PROP_NH_WHITE", "DIVERSE_PROP", 
                       "HF_PROP_RANK", "HO_PROP_RANK", "TOT_IPDAYS_PU", "TOT_COST_PB"]]

cc_super_states = cc.groupby(["STATE", "COUNTY"]).aggregate({"TOT_COST_PB":"mean", "TOT_IPDAYS_PU":"mean", 
                                                            "HF_PROP_RANK":"mean", "HO_PROP_RANK":"mean"})
cc_super_states.sort_values(by="TOT_COST_PB", ascending=False).head(20)
# Out:
#                             TOT_COST_PB  TOT_IPDAYS_PU  HF_PROP_RANK  \
# STATE          COUNTY
# Kentucky       Hickman    538250.000000      23.000000         0.483
# Nebraska       Seward     500597.666667      22.666667         0.987
# Ohio           Noble      498662.000000      17.500000         0.136
# Missouri       Bates      472382.500000       9.571429         0.122
# Kentucky       Breathitt  472226.666667      15.166667         0.067
# Nebraska       Fillmore   432855.600000      18.800000         0.920
# Louisiana      St. James  425790.000000      12.833333         0.297
# Kansas         Clark      405330.000000       3.500000         0.717
# Virginia       Amelia     404384.000000       9.000000         0.386
# Minnesota      Waseca     396079.714286       9.250000         0.718
# Indiana        Posey      385673.333333       4.428571         0.772
# Missouri       Miller     374397.428571      12.727273         0.365
# Maryland       Caroline   365903.846154      22.833333         0.125
# Texas          Dawson     362172.000000      12.200000         0.195
# Indiana        Blackford  361280.000000      16.333333         0.370
# West Virginia  Webster    341529.666667      11.500000         0.345
# North Carolina Jones      338624.666667      16.666667         0.320
# Kansas         Cherokee   323104.222222      10.111111         0.091
# North Carolina Currituck  319736.400000       9.700000         0.490
# Nebraska       Greeley    318395.000000       5.500000         0.453
#
#                           HO_PROP_RANK
# STATE          COUNTY
# Kentucky       Hickman           0.208
# Nebraska       Seward            0.933
# Ohio           Noble             0.784
# Missouri       Bates             0.774
# Kentucky       Breathitt         0.150
# Nebraska       Fillmore          0.440
# Louisiana      St. James         0.594
# Kansas         Clark             0.303
# Virginia       Amelia            0.280
# Minnesota      Waseca            0.647
# Indiana        Posey             0.696
# Missouri       Miller            0.400
# Maryland       Caroline          0.167
# Texas          Dawson            0.253
# Indiana        Blackford         0.402
# West Virginia  Webster           0.473
# North Carolina Jones             0.180
# Kansas         Cherokee          0.040
# North Carolina Currituck         0.600
# Nebraska       Greeley           0.453

# %% [markdown]
# So, this new look at the data appears to show that the Health Factor and Outcome rankings are very much spread across utilizers.  So, some low-ranked counties are high utilizers, but some are definitely not.  Also, some high-ranked counties are also high utilizers.
#
# Very interesting!!

# %%
medicare_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2947 entries, 0 to 3009
# Data columns (total 70 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS_STATE_CODE        2947 non-null   float64
#  1   FIPS_COUNTY_CODE       2947 non-null   float64
#  2   CNTY_BENE_CT           2947 non-null   int64
#  3   CNTY_BENE_USRS         2947 non-null   int64
#  4   CNTY_MEAN_AGE          2909 non-null   float64
#  5   CNTY_SEX_PROP          2947 non-null   float64
#  6   TOT_CNCR_CASES         2947 non-null   float64
#  7   TOT_STRKETIA_CASES     2947 non-null   float64
#  8   TOT_ESRD_CASES         2947 non-null   float64
#  9   CNTY_TOT_VSTS          2947 non-null   int64
#  10  CNTY_TOT_IP_VSTS       2947 non-null   int64
#  11  CNTY_TOT_OP_VSTS       2947 non-null   int64
#  12  CNTY_TOT_CODES         2947 non-null   float64
#  13  CNTY_TOT_PROCS         2947 non-null   float64
#  14  CNTY_MEAN_IP_STAY      2947 non-null   float64
#  15  CBSA                   1091 non-null   float64
#  16  CNTY_TOT_CCS           2947 non-null   float64
#  17  CNTY_MEAN_CCS          2947 non-null   float64
#  18  CNTY_TOT_NEW_CCS       2947 non-null   float64
#  19  CNTY_MEAN_NEW_CCS      2947 non-null   float64
#  20  CNTY_SUM_ELIX_SCORES   2947 non-null   float64
#  21  CNTY_TOT_IP_COST       2947 non-null   float64
#  22  CNTY_TOT_OP_COST       2947 non-null   float64
#  23  CNTY_ALL_COSTS         2947 non-null   float64
#  24  CNTY_PERCENT_COSTS     2947 non-null   float64
#  25  CNTY_USR_PROP          2947 non-null   float64
#  26  CNTY_IP_PROP           2909 non-null   float64
#  27  CNTY_AGE_95CIL         2749 non-null   float64
#  28  CNTY_AGE_95CIU         2749 non-null   float64
#  29  CNTY_PROP_NH_WHITE     2947 non-null   float64
#  30  CNTY_PROP_AA_BLACK     2947 non-null   float64
#  31  CNTY_PROP_OTHER        2947 non-null   float64
#  32  CNTY_PROP_NW_HISPANIC  2947 non-null   float64
#  33  TOT_CNCR_PREV          2947 non-null   float64
#  34  TOT_STRK_PREV          2947 non-null   float64
#  35  TOT_ESRD_PREV          2947 non-null   float64
#  36  TOT_CVRG_MOS_PB_PY     2947 non-null   float64
#  37  TOT_RXCVRG_MOS_PB_PY   2947 non-null   float64
#  38  TOT_VSTS_PB            2947 non-null   float64
#  39  TOT_VSTS_PU            2947 non-null   float64
#  40  TOT_IP_VSTS_PU         2947 non-null   float64
#  41  TOT_OP_VSTS_PU         2947 non-null   float64
#  42  CODES_PU               2947 non-null   float64
#  43  PROCS_PU               2947 non-null   float64
#  44  PRVDRS_PU              2947 non-null   float64
#  45  TOT_IPDAYS_PU          2947 non-null   float64
#  46  TOT_CC_PREV            2947 non-null   float64
#  47  TOT_CCS_PU             2947 non-null   float64
#  48  TOT_CC_INCD            2947 non-null   float64
#  49  TOT_NEW_CC_PU          2947 non-null   float64
#  50  TOT_ELIX_PU            2947 non-null   float64
#  51  TOT_IP_COST_PB         2947 non-null   float64
#  52  TOT_OP_COST_PB         2947 non-null   float64
#  53  TOT_COST_PB            2947 non-null   float64
#  54  FIPS                   2947 non-null   float64
#  55  STATE                  2947 non-null   object
#  56  COUNTY                 2947 non-null   object
#  57  NUM_COUNTIES           2947 non-null   float64
#  58  HO_RANK                2947 non-null   float64
#  59  HO_PROP_RANK           2947 non-null   float64
#  60  HO_QUARTILE            2947 non-null   float64
#  61  HF_RANK                2947 non-null   float64
#  62  HF_PROP_RANK           2947 non-null   float64
#  63  HF_QUARTILE            2947 non-null   float64
#  64  StateCode              2947 non-null   float64
#  65  CountyFIPS             2947 non-null   float64
#  66  HF_HIGH                2947 non-null   float64
#  67  HIGH_SEV               2947 non-null   float64
#  68  HIGH_PROCS             2947 non-null   float64
#  69  DIVERSE_PROP           2947 non-null   float64
# dtypes: float64(63), int64(5), object(2)
# memory usage: 1.7+ MB

# %%
medicare_counties.drop(["StateCode", "CountyFIPS"], inplace=True, axis=1, errors="ignore")

# %%
medicare_counties.to_csv("/home/kylier/python/DS/data/PUF/PUF_RWJF_MERGED.csv")
